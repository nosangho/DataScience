# %%
import requests

# %%
import json

# %%
from HTMLParser import HTMLParser

# %%
res = requests.get('http://naver.com')

# %%
print res
# Out:
# <Response [200]>

# %%
print res.status_code
# Out:
# 200

# %%
print res.text
# Out:
# <!doctype html>
# <html lang="ko">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="Content-Script-Type" content="text/javascript">
# <meta http-equiv="Content-Style-Type" content="text/css">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=960">
# <meta name="apple-mobile-web-app-title" content="NAVER" />
# <meta property="og:title" content="네이버 메인">
# <meta property="og:url" content="http://www.naver.com/">
# <meta property="og:image" content="http://static.naver.net/www/mobile/edit/2016/0705/mobile_212852414260.png">
# <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요">
# <meta name="twitter:card" content="summary">
# <meta name="twitter:title" content="네이버 메인">
# <meta name="twitter:url" content="http://www.naver.com/">
# <meta name="twitter:image" content="http://static.naver.net/www/mobile/edit/2016/0705/mobile_212852414260.png">
# ...

# %%
api_key = 'AIzaSyCMOAj0cTJkPmYzBVNiBN3W96YrZjEkZnI'
api_end_point = 'https://maps.googleapis.com/maps/api/geocode/json?address=서울특별시 서초구 서운로 6&key=' + api_key

res = requests.get(api_end_point)
print res.text
# Out:
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "6",
#                "short_name" : "6",
#                "types" : [ "political", "premise" ]
#             },
#             {
#                "long_name" : "Seoun-ro",
#                "short_name" : "Seoun-ro",
#                "types" : [ "political", "sublocality", "sublocality_level_4" ]
#             },
#             {
#                "long_name" : "Seocho-gu",
#                "short_name" : "Seocho-gu",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Seoul",
#                "short_name" : "Seoul",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "South Korea",
#                "short_name" : "KR",
#                "types" : [ "country", "political" ]
#             },
#             {
# ...

# %%
import json

# %%
import json

api_key = 'AIzaSyCMOAj0cTJkPmYzBVNiBN3W96YrZjEkZnI'
api_end_point = 'https://maps.googleapis.com/maps/api/geocode/json?address=서울특별시 서초구 서운로 6&key=' + api_key

res = requests.get(api_end_point)
data = json.loads(res.text) # loads method이용

latlng = data['results'][0]['geometry']['location']
print latlng['lat']
print latlng['lng']
# Out:
# 37.4846743
# 127.0298918

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
def get_naver_title(url):
    response = request.get(url)
    content = response.txt
    
    soup = BeautifulSoup(content)
    title = soup.title.get_text()
    
    return title

def get_naver_contents(url):
    response = requests.get(url)
    content = response.text
    
    soup = BeautifulSoup(content, "html5lib")
    
    div = soup.find('div', attrs = {'id' : 'articleBodyContents'})
    
    content = div.get_text()
    
    return content.encode('utf-8')

# %%
new1 = get_naver_contents('http://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=469&aid=0000184888')
print new1
# Out:
#
#
#
#
#
# // flash 오류를 우회하기 위한 함수 추가
# function _flash_removeCallback() {}
#
#
# ...

# %%
import requests
import json
from HTMLParser import HTMLParser

api_key = '66bf527d37b4d77226fca6b744703528'
url = 'https://apis.daum.net/search/web?apikey={}&q={}&output=json'.format(api_key, '갤럭시 노트 7')

res = requests.get(url)
data = json.loads(res.text)

h = HTMLParser()
print data['channel']['item'][0]['title']
print h.unescape(data['channel']['item'][0]['title'])

# %%
client_key = 'FoYXAgmX7P6iY57tTVlW'
client_secret = 'lJrcjV20nE'

naver_url = 'https://openapi.naver.com/v1/search/blog.json?query=쉑쉑버거'

headers = {}
headers['Content-Type'] = 'application/xml'
headers['X-Naver-Client-Id'] = client_key
headers['X-Naver-Client-Secret'] = client_secret

res = requests.get(naver_url, headers = headers)
print res.text
# Out:
# {
# "lastBuildDate": "Tue, 24 Jan 2017 12:58:32 +0900",
# "total": 49651,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "청담동 맛집 - <b>쉑쉑버거</b> 2호점 청담 : 추천 메뉴 및 가격",
# "link": "http://blog.naver.com/teemoticon?Redirect=Log&amp;logNo=220910337924",
# "description": "[ 청담동 맛집 - <b>쉑쉑버거</b>(Shake Shack) 청담점 ] 안녕하세요 티이모에요 ^오^ <b>쉑쉑버거</b>가 작년 7월에 우리나라 강남역 역삼동에 처음 자리 잡고 엄청난 광풍을 일으켰는데 한동안 기다리는 줄이 줄어드나 했는데... ",
# "bloggername": "티이모와의 연결 고리 ♂",
# "bloggerlink": "http://blog.naver.com/teemoticon",
# "postdate": "20170113"
#
# },
# {
# "title": "<b>쉑쉑버거</b> 메뉴 이게 갑인 듯 b",
# "link": "http://blog.naver.com/hongdaeobba?Redirect=Log&amp;logNo=220890195363",
# "description": "여전히 웨이팅은 필수 강남 <b>쉑쉑버거</b> 1호점 쉐이크가 너무 생각나서 오랜만에 <b>쉑쉑버거</b> 강남점 방문 여전히 기다리는 사람들이 많은 강남 <b>쉑쉑버거</b> 열기가 식지 않는구나. 여름에 갔을 때 인생 웨이팅 한... ",
# "bloggername": "홍대bro 블로그",
# "bloggerlink": "http://blog.naver.com/hongdaeobba",
# "postdate": "20161220"
#
# },
# {
# "title": "강남 <b>쉑쉑버거</b> 가격 , 메뉴 , 주차 드디어먹어봤다!!",
# ...
